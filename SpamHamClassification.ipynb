# %% [markdown]
# <a href="https://colab.research.google.com/github/MS-105/SpamHamClassification/blob/main/SpamHamClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📩 SMS Spam Classification using Machine Learning
#
# ## 🔍 Project Overview
#
# In this project, I am building a **Spam vs Ham (Not Spam) classifier** using a real-world SMS dataset.
#
# The goal is to train a machine learning model that can automatically classify incoming messages as:
#
# - **Spam** → Unwanted promotional or fraudulent messages
# - **Ham** → Legitimate personal messages
#
# ---
#
# ## 🧠 What This Project Demonstrates
#
# - Text preprocessing
# - Feature extraction using **TF-IDF Vectorization**
# - Supervised Machine Learning
# - Model training and evaluation
# - Real-time message prediction
#
# This project shows how raw text data can be converted into numerical form and used to train a classification model.
#
# ---
#
# ## 📂 Dataset Used
#
# - SMS Spam Collection Dataset
# - Contains labeled messages (spam or ham)
# - Real-world text data used for binary classification
#
# ---
#
# ## ⚙️ Technologies Used
#
# - Python
# - Pandas
# - Scikit-learn
# - Google Colab
#
# ---
#
# ## 🚀 Workflow
#
# 1. Load and clean dataset
# 2. Select relevant columns
# 3. Convert text into numerical features using TF-IDF
# 4. Train a Naive Bayes classifier
# 5. Evaluate model performance
# 6. Test with custom messages
#
# ---
#
# ## 🎯 Objective
#
# To understand how Natural Language Processing (NLP) and Machine Learning can be applied to solve real-world classification problems.

# %%
import kagglehub
path = kagglehub.dataset_download("uciml/sms-spam-collection-dataset")
# Out:
# Using Colab cache for faster access to the 'sms-spam-collection-dataset' dataset.

# %%
path
# Out:
# '/kaggle/input/sms-spam-collection-dataset'

# %%
import os
#os.listdir(path)
file_path = os.path.join(path, "spam.csv")
file_path
# Out:
# '/kaggle/input/sms-spam-collection-dataset/spam.csv'

# %%
import pandas as pd
message = pd.read_csv(file_path, encoding='latin-1')
message = message.iloc[:, :2]   # take only first 2 columns
message.columns = ['label', 'message'] # rename

# %%
message.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
#data cleaning and pre processing
import re
import nltk
nltk.download('stopwords') #unnecessary words
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
corpus = []

for i in range(0,len(message)):
  review = re.sub( )
